# %% [markdown]
# The project analyzes a dataset and performs web scraping.
#
# The Ratings class analyzes ratings.csv:
# * examines movie ratings, who rates them, and when
#
# The Tags class processes tags.csv:
# * what tags users assign, which are most popular, longest, word-rich, and interesting
#
# The Movies class examines movies.csv:
# * Movies, genres, titles
#
# And the Links class scrapes the website + processes links.csv
# * loads website data and implements caching
# * builds methods based on scraped website data

# %%
from movielens_analysis import Ratings
from movielens_analysis import Tags
from movielens_analysis import Movies
from movielens_analysis import Links


print("Initializing Ratings system...")
# %timeit r = Ratings('data/ml-latest-small/ratings.csv')
r = Ratings('data/ml-latest-small/ratings.csv')
print("System ready!")
print(f"Data loaded: {len(r.ratings_data)} ratings")
print('p.s. each method is limited to the first 1000 rows')
# Out:
# Initializing Ratings system...
# 15.9 ms ± 514 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# System ready!
# Data loaded: 1000 ratings
# p.s. each method is limited to the first 1000 rows

# %%
# Which year had the most film productions?
print("Analyzing movie distribution by year...")
# %timeit years_data = r.movies.dist_by_year()
years_data = r.movies.dist_by_year()

top_year = max(years_data, key=years_data.get)
top_count = years_data[top_year]

print(f"Most productive film year - {top_year}!")
print(f"Users gave {top_count} ratings this year")
# Out:
# Analyzing movie distribution by year...
# 813 μs ± 17.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Most productive film year - 1996!
# Users gave 358 ratings this year

# %%
# Which ratings are given most frequently?
print("Examining rating distribution...")
# %timeit rating_dist = r.movies.dist_by_rating()
rating_dist = r.movies.dist_by_rating()

most_common_rating = max(rating_dist, key=rating_dist.get)
most_common_count = rating_dist[most_common_rating]

print(f"Most common rating - {most_common_rating} ⭐!")
print(f"Given {most_common_count} times, wow")
print("Full distribution:")
for rating, count in sorted(rating_dist.items()):
    print(f"  {rating} ⭐: {count} ratings")
# Out:
# Examining rating distribution...
# 287 μs ± 4.52 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Most common rating - 4.0 ⭐!
# Given 292 times, wow
# Full distribution:
#   0.5 ⭐: 24 ratings
#   1.0 ⭐: 39 ratings
#   1.5 ⭐: 11 ratings
#   2.0 ⭐: 57 ratings
#   2.5 ⭐: 7 ratings
#   3.0 ⭐: 253 ratings
#   3.5 ⭐: 17 ratings
#   4.0 ⭐: 292 ratings
#   4.5 ⭐: 33 ratings
#   5.0 ⭐: 267 ratings

# %%
print("Which movies are most discussed?")
# %timeit top_by_count = r.movies.top_by_num_of_ratings(5)
top_by_count = r.movies.top_by_num_of_ratings(5)

print("TOP-5 movies by rating count:")
for i, (movie, count) in enumerate(top_by_count.items(), 1):
    print(f"{i}. {movie} - ratings count: {count} ")
# Out:
# Which movies are most discussed?
# 803 μs ± 21.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# TOP-5 movies by rating count:
# 1. Usual Suspects, The (1995) - ratings count: 4
# 2. Pulp Fiction (1994) - ratings count: 4
# 3. Fugitive, The (1993) - ratings count: 4
# 4. Schindler's List (1993) - ratings count: 4
# 5. Batman (1989) - ratings count: 4

# %% [markdown]
# This method's output depends on the chosen metric - either mean or median. Results may differ.
# This is normal.

# %%
print("Best movies (after Harry Potter)")
# %timeit top_mean = r.movies.top_by_ratings(5, 'mean')
top_mean = r.movies.top_by_ratings(5, 'mean')

# %timeit top_median = r.movies.top_by_ratings(5, 'median')
top_median = r.movies.top_by_ratings(5, 'median')

print("TOP-5 by average rating:")
for i, (movie, rating) in enumerate(top_mean.items(), 1):
    print(f"{i}. {movie}: {rating} ⭐")

print("TOP-5 by median rating:")
for i, (movie, rating) in enumerate(top_median.items(), 1):
    print(f"{i}. {movie}: {rating} ⭐")
# Out:
# Best movies (after Harry Potter)
# 1.97 ms ± 73.3 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 2.09 ms ± 38.4 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# TOP-5 by average rating:
# 1. Bottle Rocket (1996): 5.0 ⭐
# 2. Canadian Bacon (1995): 5.0 ⭐
# 3. Star Wars: Episode IV - A New Hope (1977): 5.0 ⭐
# 4. James and the Giant Peach (1996): 5.0 ⭐
# 5. Wizard of Oz, The (1939): 5.0 ⭐
# TOP-5 by median rating:
# 1. Bottle Rocket (1996): 5.0 ⭐
# 2. Canadian Bacon (1995): 5.0 ⭐
# 3. Star Wars: Episode IV - A New Hope (1977): 5.0 ⭐
# 4. Tommy Boy (1995): 5.0 ⭐
# 5. Forrest Gump (1994): 5.0 ⭐

# %%
# Which movies are watched most on weekends?

print("Weekend movies")
# %timeit weekend_hits = r.movies.weekend_hits(5)
weekend_hits = r.movies.weekend_hits(5)


print("TOP-5 weekend movies (weekend rating ratio):")

for i, (movie, ratio) in enumerate(weekend_hits.items(), 1):
    print(f"{i}. {movie}: {ratio*100:.1f}% ratings on weekends")
# Out:
# Weekend movies
# 1.48 ms ± 33.8 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# TOP-5 weekend movies (weekend rating ratio):
# 1. Good Will Hunting (1997): 100.0% ratings on weekends
# 2. Tommy Boy (1995): 67.0% ratings on weekends
# 3. Gladiator (2000): 67.0% ratings on weekends
# 4. Grumpier Old Men (1995): 50.0% ratings on weekends
# 5. Heat (1995): 50.0% ratings on weekends

# %%
print("Which movies are most controversial?")
# %timeit controversial = r.movies.top_controversial(5)
controversial = r.movies.top_controversial(5)

print("TOP-5 most controversial movies (by rating variance):")
for i, (movie, variance) in enumerate(controversial.items(), 1):
    print(f"{i}. {movie}: variance {variance} 🆘")
# Out:
# Which movies are most controversial?
# 1.43 ms ± 37.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# TOP-5 most controversial movies (by rating variance):
# 1. Bambi (1942): variance 5.06 🆘
# 2. Rescuers, The (1977): variance 5.06 🆘
# 3. My Fair Lady (1964): variance 5.06 🆘
# 4. Matrix, The (1999): variance 4.0 🆘
# 5. Schindler's List (1993): variance 3.42 🆘

# %%
# Who is the most active user?
print("Top movie critics ranking")
# %timeit user_activity = r.users.dist_by_num_ratings()
user_activity = r.users.dist_by_num_ratings()

most_active_user = list(user_activity.keys())[0]
most_active_count = user_activity[most_active_user]

print(f"Most active user (ID: {most_active_user}) gave {most_active_count} ratings!")
print(f"Total active users: {len(user_activity)}")
# Out:
# Top movie critics ranking
# 215 μs ± 6.53 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Most active user (ID: 6) gave 314 ratings!
# Total active users: 7

# %% [markdown]
# Yes, there are only 7 users total

# %%
# Who are the most generous critics?
print("Checking users with highest average ratings...")
# %timeit user_ratings = r.users.dist_by_avg_ratings()
user_ratings = r.users.dist_by_avg_ratings()

top_raters = dict(list(user_ratings.items())[:5])
print("TOP-5 most generous users:")
for i, (user_id, avg_rating) in enumerate(top_raters.items(), 1):
    print(f"{i}. User {user_id}: average rating {avg_rating} ⭐")
# Out:
# Checking users with highest average ratings...
# 242 μs ± 17.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# TOP-5 most generous users:
# 1. User 1: average rating 4.37 ⭐
# 2. User 2: average rating 3.95 ⭐
# 3. User 5: average rating 3.64 ⭐
# 4. User 4: average rating 3.56 ⭐
# 5. User 6: average rating 3.49 ⭐

# %%
# Who are our night monsters?
print("Finding users who rate movies at night...")
# %timeit night_owls = r.users.night_monsters(5)
night_owls = r.users.night_monsters(5)

print("TOP-5 night monsters (ratings between 10 PM and 6 AM):")
for i, (user_id, ratio) in enumerate(night_owls.items(), 1):
    print(f"{i}. User {user_id}: {ratio*100:.1f}% night ratings")
# Out:
# Finding users who rate movies at night...
# 991 μs ± 36.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# TOP-5 night monsters (ratings between 10 PM and 6 AM):
# 1. User 2: 100.0% night ratings
# 2. User 3: 100.0% night ratings
# 3. User 4: 25.0% night ratings
# 4. User 7: 14.0% night ratings
# 5. User 1: 12.0% night ratings

# %%
# Who is the most unpredictable?
print("Finding users with most unpredictable ratings...")
# %timeit controversial_users = r.users.top_controversial_users(5)
controversial_users = r.users.top_controversial_users(5)

print("TOP-5 most unpredictable users (by rating variance):")
for i, (user_id, variance) in enumerate(controversial_users.items(), 1):
    print(f"{i}. User {user_id}: variance {variance}")
# Out:
# Finding users with most unpredictable ratings...
# 514 μs ± 27 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# TOP-5 most unpredictable users (by rating variance):
# 1. User 3: variance 4.26
# 2. User 4: variance 1.72
# 3. User 7: variance 1.65
# 4. User 5: variance 0.96
# 5. User 6: variance 0.72

# %% [markdown]
# Ratings analysis complete! We learned interesting insights and are exhausted.
# Enjoy watching! I recommend starting with Harry Potter :)

# %% [markdown]
# Moving to Links

# %%
print ('Initialization second...')

links = Links()
# Out:
# Initialization second...

# %%
print('Fetching data from cache:')

# %timeit -r1 -n1
get_data = links.get_imdb([1, 2, 3], ['title', 'director', 'runtime'])
print(get_data)
# Out:
# Fetching data from cache:
# [[3, 'Старые ворчуны разбушевались', 'Howard Deutch', 101], [2, 'Джуманджи', 'Joe Johnston', 104], [1, 'История игрушек', 'John Lasseter', 81]]

# %%
print ('Method returns top directors by number of films:')

# %timeit -r1 -n1
t_directors = links.top_directors(5)
for director in t_directors:
    print(director)
# Out:
# Method returns top directors by number of films:
# Alfred Hitchcock
# Woody Allen
# Frank Capra
# Stanley Kubrick
# Steven Spielberg

# %%
print('Top most expensive movies:')

# %timeit -r1 -n1
m_expensive = links.most_expensive(5)
for rich in m_expensive:
    print(f'{rich}💸')
# Out:
# Top most expensive movies:
# Звёздные войны: Эпизод 4 - Новая надежда💸
# E.T. the Extra-Terrestrial💸
# Король лев💸
# Парк юрского периода💸
# Форрест Гамп💸

# %%
print('And these are the most profitable movies:')

# %timeit -r1 -n1
m_profitable = links.most_profitable(5)
for profit in m_profitable:
    print(profit)
# Out:
# And these are the most profitable movies:
# Парк юрского периода
# Король лев
# День независимости
# E.T. the Extra-Terrestrial
# Форрест Гамп

# %%
print('Longest movies?')
# %timeit -r1 -n1
m_longest = links.longest(5)
print('ТОП:')
for long in m_longest:
    print(long)
# Out:
# Longest movies?
# ТОП:
# Андеграунд
# Унесённые ветром
# Танцующий с волками
# Лоуренс Аравийский
# Однажды в Америке

# %%
print('Most expensive movies PER MINUTE of screen time:')

# %timeit -r1 -n1
t_per_min = links.top_cost_per_minute(5)
for min in t_per_min:
    print(min)
# Out:
# Most expensive movies PER MINUTE of screen time:
# День независимости
# Парк юрского периода
# Горячие головы 2
# Рыбка по имени Ванда
# Узы братства

# %%
print("Let's check movies by specific director, e.g., John Lasseter:")
# %timeit -r1 -n1
m_by_director = links.movies_by_director("John Lasseter")
print(m_by_director)
# Out:
# Let's check movies by specific director, e.g., John Lasseter:
# ['История игрушек']

# %%
print('Checking the last method of this class :)')

# %timeit -r1 -n1
shortest = links.shortest_movie()
print ('Shortest film...')
print (shortest)
# Out:
# Checking the last method of this class :)
# Shortest film...
# Любовь и 45 калибр

# %% [markdown]
# Moving to the next class - Movies. It's small, only 3 methods

# %%
movies = Movies('data/ml-latest-small/movies.csv')

# %%
# %timeit -r1 -n1
years = movies.dist_by_release()
print("Top-5 years by film count:")
for year, count in list(years.items())[:5]:
    print(f"  {year}: {count} films")
# Out:
# Top-5 years by film count:
#   1995: 180 films
#   1994: 141 films
#   1996: 141 films
#   1993: 83 films
#   1992: 18 films

# %%
# %timeit -r1 -n1
genres = movies.dist_by_genres()
print("Top-5 genres:")
for genre, count in list(genres.items())[:5]:
    print(f"  {genre}: {count} films")
# Out:
# Top-5 genres:
#   Drama: 438 films
#   Comedy: 311 films
#   Romance: 207 films
#   Thriller: 178 films
#   Action: 121 films

# %%
# %timeit -r1 -n1
multi_genres = movies.most_genres(5)
print("Top movies with most genres:")
for title, count in multi_genres.items():
    print(f"  {title}: {count} genres")
# Out:
# Top movies with most genres:
#   Strange Days (1995): 6 genres
#   "Lion King: 6 genres
#   "Getaway: 6 genres
#   Super Mario Bros. (1993): 6 genres
#   Beauty and the Beast (1991): 6 genres
#   All Dogs Go to Heaven 2 (1996): 6 genres
#   Space Jam (1996): 6 genres
#   Aladdin and the King of Thieves (1996): 6 genres
#   Toy Story (1995): 5 genres
#   Money Train (1995): 5 genres
#   Copycat (1995): 5 genres
#   "City of Lost Children: 5 genres
#   Pocahontas (1995): 5 genres
#   Bad Boys (1995): 5 genres
#   "Kid in King Arthur's Court: 5 genres
#   True Lies (1994): 5 genres
#   RoboCop 3 (1993): 5 genres
#   "Pagemaster: 5 genres
#   Ghost (1990): 5 genres
#   Aladdin (1992): 5 genres
#   Snow White and the Seven Dwarfs (1937): 5 genres
#   Heavy Metal (1981): 5 genres
#   James and the Giant Peach (1996): 5 genres
#   "Alphaville (Alphaville: 5 genres
#   Oliver & Company (1988): 5 genres
#   "Hunchback of Notre Dame: 5 genres
#   North by Northwest (1959): 5 genres
#   Charade (1963): 5 genres
#   Beat the Devil (1953): 5 genres
#   Cinderella (1950): 5 genres
#   Alice in Wonderland (1951): 5 genres
#   "Princess Bride: 5 genres
#   Army of Darkness (1993): 5 genres
#   "Grand Day Out with Wallace and Gromit: 5 genres
#   Diva (1981): 5 genres
#   From Dusk Till Dawn (1996): 4 genres
#   "Crossing Guard: 4 genres
#   Bottle Rocket (1996): 4 genres
#   Muppet Treasure Island (1996): 4 genres
#   Rumble in the Bronx (Hont faan kui) (1995): 4 genres
#   Rob Roy (1995): 4 genres
#   Batman Forever (1995): 4 genres
#   Congo (1995): 4 genres
#   Devil in a Blue Dress (1995): 4 genres
#   Hackers (1995): 4 genres
#   Bushwhacked (1995): 4 genres
#   "Goofy Movie: 4 genres
#   Legends of the Fall (1994): 4 genres
#   Outbreak (1995): 4 genres
#   Léon: The Professional (a.k.a. The Professional) (Léon) (1994): 4 genres
#   Pulp Fiction (1994): 4 genres
#   "Secret of Roan Inish: 4 genres
#   Clear and Present Danger (1994): 4 genres
#   "Crow: 4 genres
#   Forrest Gump (1994): 4 genres
#   "Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale: 4 genres
#   "Mask: 4 genres
#   Wolf (1994): 4 genres
#   Beverly Hills Cop III (1994): 4 genres
#   Boxing Helena (1993): 4 genres
#   Hard Target (1993): 4 genres
#   Jurassic Park (1993): 4 genres
#   Last Action Hero (1993): 4 genres
#   What Happened Was... (1994): 4 genres
#   "Shadow: 4 genres
#   "Nightmare Before Christmas: 4 genres
#   "Three Musketeers: 4 genres
#   Pinocchio (1940): 4 genres
#   Fargo (1996): 4 genres
#   Primal Fear (1996): 4 genres
#   Courage Under Fire (1996): 4 genres
#   Mission: Impossible (1996): 4 genres
#   Operation Dumbo Drop (1995): 4 genres
#   "Craft: 4 genres
#   Twister (1996): 4 genres
#   Independence Day (a.k.a. ID4) (1996): 4 genres
#   "Nutty Professor: 4 genres
#   Daylight (1996): 4 genres
#   Escape from L.A. (1996): 4 genres
#   Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992): 4 genres
#   Bound (1996): 4 genres
#   Kansas City (1996): 4 genres
#   Supercop 2 (Project S) (Chao ji ji hua) (1993): 4 genres
#   Land Before Time III: The Time of the Great Giving (1995): 4 genres
#   For Whom the Bell Tolls (1943): 4 genres
#   Vertigo (1958): 4 genres
#   My Fair Lady (1964): 4 genres
#   "Wizard of Oz: 4 genres
#   Rebecca (1940): 4 genres
#   Foreign Correspondent (1940): 4 genres
#   To Catch a Thief (1955): 4 genres
#   It's a Wonderful Life (1946): 4 genres
#   "African Queen: 4 genres
#   Last Man Standing (1996): 4 genres
#   Herbie Rides Again (1974): 4 genres
#   "Sword in the Stone: 4 genres
#   Mary Poppins (1964): 4 genres
#   Dumbo (1941): 4 genres
#   Pete's Dragon (1977): 4 genres
#   Freeway (1996): 4 genres
#   "Lawnmower Man: 4 genres
#   Willy Wonka & the Chocolate Factory (1971): 4 genres
#   "Abyss: 4 genres
#   Escape from New York (1981): 4 genres
#   Wallace & Gromit: The Wrong Trousers (1993): 4 genres
#   Lesson Faust (1994): 4 genres
#   Aliens (1986): 4 genres
#   "Clockwork Orange: 4 genres
#   "Killer: 4 genres
#   Henry V (1989): 4 genres
#   Miller's Crossing (1990): 4 genres
#   "Femme Nikita: 4 genres
#   Chinatown (1974): 4 genres
#   "Treasure of the Sierra Madre: 4 genres
#   Evil Dead II (Dead by Dawn) (1987): 4 genres
#   "Great Escape: 4 genres
#   Akira (1988): 4 genres
#   Fantasia (1940): 4 genres
#   Jumanji (1995): 3 genres
#   Waiting to Exhale (1995): 3 genres
#   Heat (1995): 3 genres
#   GoldenEye (1995): 3 genres
#   "American President: 3 genres
#   Balto (1995): 3 genres
#   Cutthroat Island (1995): 3 genres
#   Get Shorty (1995): 3 genres
#   Assassins (1995): 3 genres
#   Twelve Monkeys (a.k.a. 12 Monkeys) (1995): 3 genres
#   Dead Presidents (1995): 3 genres
#   Mortal Kombat (1995): 3 genres
#   To Die For (1995): 3 genres
#   "Usual Suspects: 3 genres
#   Mighty Aphrodite (1995): 3 genres
#   "Postman: 3 genres
#   "Indian in the Cupboard: 3 genres
#   Lawnmower Man 2: Beyond Cyberspace (1996): 3 genres
#   Screamers (1995): 3 genres
#   Things to Do in Denver When You're Dead (1995): 3 genres
#   White Squall (1996): 3 genres
#   Mary Reilly (1996): 3 genres
#   Vampire in Brooklyn (1995): 3 genres
#   Beautiful Girls (1996): 3 genres
#   Broken Arrow (1996): 3 genres
#   Unforgettable (1996): 3 genres
#   Braveheart (1995): 3 genres
#   Taxi Driver (1976): 3 genres
#   Chungking Express (Chung Hing sam lam) (1994): 3 genres
#   "NeverEnding Story III: 3 genres
#   Amateur (1994): 3 genres
#   Apollo 13 (1995): 3 genres
#   Beyond Rangoon (1995): 3 genres
#   Clockers (1995): 3 genres
#   Crimson Tide (1995): 3 genres
#   Desperado (1995): 3 genres
#   Die Hard: With a Vengeance (1995): 3 genres
#   "Doom Generation: 3 genres
#   First Knight (1995): 3 genres
#   Free Willy 2: The Adventure Home (1995): 3 genres
#   Johnny Mnemonic (1995): 3 genres
#   Judge Dredd (1995): 3 genres
#   Mute Witness (1994): 3 genres
#   "Net: 3 genres
#   "Prophecy: 3 genres
#   Something to Talk About (1995): 3 genres
#   "Umbrellas of Cherbourg: 3 genres
#   Waterworld (1995): 3 genres
#   Don Juan DeMarco (1995): 3 genres
#   Eat Drink Man Woman (Yin shi nan nu) (1994): 3 genres
#   French Kiss (1995): 3 genres
#   Gordy (1995): 3 genres
#   Kiss of Death (1995): 3 genres
#   Star Wars: Episode IV - A New Hope (1977): 3 genres
#   Like Water for Chocolate (Como agua para chocolate) (1992): 3 genres
#   Mary Shelley's Frankenstein (Frankenstein) (1994): 3 genres
#   Nobody's Fool (1994): 3 genres
#   Natural Born Killers (1994): 3 genres
#   "Quick and the Dead: 3 genres
#   "Specialist: 3 genres
#   Stargate (1994): 3 genres
#   "Santa Clause: 3 genres
#   Shallow Grave (1994): 3 genres
#   Tank Girl (1995): 3 genres
#   Star Trek: Generations (1994): 3 genres
#   Tales from the Hood (1995): 3 genres
#   Virtuosity (1995): 3 genres
#   "War: 3 genres
#   Bitter Moon (1992): 3 genres
#   "Client: 3 genres
#   "Corrina: 3 genres
#   "Flintstones: 3 genres
#   I Like It Like That (1994): 3 genres
#   It Could Happen to You (1994): 3 genres
#   "Jungle Book: 3 genres
#   Maverick (1994): 3 genres
#   Reality Bites (1994): 3 genres
#   Speed (1994): 3 genres
#   Timecop (1994): 3 genres
#   Bad Company (1995): 3 genres
#   "Colonel Chabert: 3 genres
#   Faster Pussycat! Kill! Kill! (1965): 3 genres
#   Street Fighter (1994): 3 genres
#   Addams Family Values (1993): 3 genres
#   Black Beauty (1994): 3 genres
#   Body Snatchers (1993): 3 genres
#   City Slickers II: The Legend of Curly's Gold (1994): 3 genres
#   Cliffhanger (1993): 3 genres
#   "Cowboy Way: 3 genres
#   Demolition Man (1993): 3 genres
#   Flesh and Bone (1993): 3 genres
#   Free Willy (1993): 3 genres
#   Fresh (1994): 3 genres
#   Hot Shots! Part Deux (1993): 3 genres
#   Jimmy Hollywood (1994): 3 genres
#   Judgment Night (1993): 3 genres
#   Killing Zoe (1994): 3 genres
#   Menace II Society (1993): 3 genres
#   Executive Decision (1996): 3 genres
#   "Next Karate Kid: 3 genres
#   No Escape (1994): 3 genres
#   Orlando (1992): 3 genres
#   "Perfect World: 3 genres
#   Radioland Murders (1994): 3 genres
#   Rising Sun (1993): 3 genres
#   Serial Mom (1994): 3 genres
#   Sleepless in Seattle (1993): 3 genres
#   Blade Runner (1982): 3 genres
#   Son in Law (1993): 3 genres
#   So I Married an Axe Murderer (1993): 3 genres
#   Surviving the Game (1994): 3 genres
#   Terminal Velocity (1994): 3 genres
#   Tombstone (1993): 3 genres
#   Andre (1994): 3 genres
#   Dances with Wolves (1990): 3 genres
#   Batman (1989): 3 genres
#   "Silence of the Lambs: 3 genres
#   Love and a .45 (1994): 3 genres
#   Hellraiser: Bloodline (1996): 3 genres
#   Dragonheart (1996): 3 genres
#   Underground (1995): 3 genres
#   Barbarella (1968): 3 genres
#   Solo (1996): 3 genres
#   "Substitute: 3 genres
#   Mulholland Falls (1996): 3 genres
#   Dead Man (1995): 3 genres
#   "Visitors: 3 genres
#   Wallace & Gromit: The Best of Aardman Animation (1996): 3 genres
#   "Rock: 3 genres
#   Wallace & Gromit: A Close Shave (1995): 3 genres
#   "Arrival: 3 genres
#   Trainspotting (1996): 3 genres
#   Eraser (1996): 3 genres
#   "Frighteners: 3 genres
#   Lone Star (1996): 3 genres
#   Walking and Talking (1996): 3 genres
#   Kazaam (1996): 3 genres
#   Joe's Apartment (1996): 3 genres
#   Chain Reaction (1996): 3 genres
#   Matilda (1996): 3 genres
#   Emma (1996): 3 genres
#   Tin Cup (1996): 3 genres
#   Nothing to Lose (1994): 3 genres
#   Bogus (1996): 3 genres
#   Bulletproof (1996): 3 genres
#   Twelfth Night (1996): 3 genres
#   "Philadelphia Story: 3 genres
#   Singin' in the Rain (1952): 3 genres
#   "Gay Divorcee: 3 genres
#   "Apartment: 3 genres
#   Roman Holiday (1953): 3 genres
#   Gone with the Wind (1939): 3 genres
#   Sunset Blvd. (a.k.a. Sunset Boulevard) (1950): 3 genres
#   2001: A Space Odyssey (1968): 3 genres
#   Notorious (1946): 3 genres
#   Spellbound (1945): 3 genres
#   "Adventures of Robin Hood: 3 genres
#   Laura (1944): 3 genres
#   "Ghost and Mrs. Muir: 3 genres
#   Top Hat (1935): 3 genres
#   To Be or Not to Be (1942): 3 genres
#   Giant (1956): 3 genres
#   "39 Steps: 3 genres
#   Night of the Living Dead (1968): 3 genres
#   Maximum Risk (1996): 3 genres
#   "Apple Dumpling Gang: 3 genres
#   Escape to Witch Mountain (1975): 3 genres
#   "Parent Trap: 3 genres
#   Pollyanna (1960): 3 genres
#   Homeward Bound: The Incredible Journey (1993): 3 genres
#   That Darn Cat! (1965): 3 genres
#   "20: 3 genres
#   Winnie the Pooh and the Blustery Day (1968): 3 genres
#   "Three Caballeros: 3 genres
#   Bedknobs and Broomsticks (1971): 3 genres
#   "Fox and the Hound: 3 genres
#   Die Hard (1988): 3 genres
#   "Long Kiss Goodnight: 3 genres
#   Normal Life (1996): 3 genres
#   Everyone Says I Love You (1996): 3 genres
#   Shall We Dance (1937): 3 genres
#   "Innocents: 3 genres
#   Victor/Victoria (1982): 3 genres
#   Dial M for Murder (1954): 3 genres
#   Dirty Dancing (1987): 3 genres
#   Reservoir Dogs (1992): 3 genres
#   Basic Instinct (1992): 3 genres
#   "Crying Game: 3 genres
#   E.T. the Extra-Terrestrial (1982): 3 genres
#   "Christmas Carol: 3 genres
#   Days of Thunder (1990): 3 genres
#   Palookaville (1996): 3 genres
#   Monty Python and the Holy Grail (1975): 3 genres
#   Delicatessen (1991): 3 genres
#   "Double Life of Veronique: 3 genres
#   "Grifters: 3 genres
#   "English Patient: 3 genres
#   Tie Me Up! Tie Me Down! (¡Átame!) (1990): 3 genres
#   Star Wars: Episode V - The Empire Strikes Back (1980): 3 genres
#   "Good: 3 genres
#   Lawrence of Arabia (1962): 3 genres
#   Apocalypse Now (1979): 3 genres
#   Once Upon a Time in the West (C'era una volta il West) (1968): 3 genres
#   Star Wars: Episode VI - Return of the Jedi (1983): 3 genres
#   "Wings of Desire (Himmel über Berlin: 3 genres
#   "Third Man: 3 genres
#   "Big Blue: 3 genres
#   "Blues Brothers: 3 genres
#   Stalker (1979): 3 genres
#   "Boot: 3 genres
#   Harold and Maude (1971): 3 genres
#   Trust (1990): 3 genres
#   "Terminator: 3 genres
#   Dead Alive (Braindead) (1992): 3 genres
#   Manhattan (1979): 3 genres
#   "Graduate: 3 genres
#   Touch of Evil (1958): 3 genres
#   "Bridge on the River Kwai: 3 genres
#   "Day the Earth Stood Still: 3 genres
#   Bad Taste (1987): 3 genres
#   Duck Soup (1933): 3 genres
#   M (1931): 3 genres
#   Groundhog Day (1993): 3 genres
#   "Manchurian Candidate: 3 genres
#   Arsenic and Old Lace (1944): 3 genres
#   Back to the Future (1985): 3 genres
#   Fried Green Tomatoes (1991): 3 genres
#   Down by Law (1986): 3 genres
#   Highlander (1986): 3 genres
#   Cyrano de Bergerac (1990): 3 genres
#   "Great Dictator: 3 genres
#   "Big Sleep: 3 genres
#   Ben-Hur (1959): 3 genres
#   Grumpier Old Men (1995): 2 genres
#   Sabrina (1995): 2 genres
#   Tom and Huck (1995): 2 genres
#   Dracula: Dead and Loving It (1995): 2 genres
#   Casino (1995): 2 genres
#   Sense and Sensibility (1995): 2 genres
#   Powder (1995): 2 genres
#   Leaving Las Vegas (1995): 2 genres
#   Now and Then (1995): 2 genres
#   Persuasion (1995): 2 genres
#   Shanghai Triad (Yao a yao yao dao waipo qiao) (1995): 2 genres
#   Babe (1995): 2 genres
#   Dead Man Walking (1995): 2 genres
#   It Takes Two (1995): 2 genres
#   Clueless (1995): 2 genres
#   Richard III (1995): 2 genres
#   How to Make an American Quilt (1995): 2 genres
#   Seven (a.k.a. Se7en) (1995): 2 genres
#   When Night Is Falling (1995): 2 genres
#   Lamerica (1994): 2 genres
#   "Big Green: 2 genres
#   Eye for an Eye (1996): 2 genres
#   Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996): 2 genres
#   Two if by Sea (1996): 2 genres
#   French Twist (Gazon maudit) (1995): 2 genres
#   Kicking and Screaming (1995): 2 genres
#   "Misérables: 2 genres
#   Bed of Roses (1996): 2 genres
#   Big Bully (1996): 2 genres
#   "Juror: 2 genres
#   "White Balloon: 2 genres
#   Antonia's Line (Antonia) (1995): 2 genres
#   Once Upon a Time... When We Were Colored (1995): 2 genres
#   Angels and Insects (1995): 2 genres
#   Dunston Checks In (1996): 2 genres
#   Nick of Time (1995): 2 genres
#   In the Bleak Midwinter (1995): 2 genres
#   "Hate (Haine: 2 genres
#   City Hall (1996): 2 genres
#   "Bridges of Madison County: 2 genres
#   Nobody Loves Me (Keiner liebt mich) (1994): 2 genres
#   Before and After (1996): 2 genres
#   "Young Poisoner's Handbook: 2 genres
#   If Lucy Fell (1996): 2 genres
#   Boomerang (1992): 2 genres
#   Pie in the Sky (1996): 2 genres
#   Up Close and Personal (1996): 2 genres
#   "Amazing Panda Adventure: 2 genres
#   "Addiction: 2 genres
#   Blue in the Face (1995): 2 genres
#   Canadian Bacon (1995): 2 genres
#   Casper (1995): 2 genres
#   Jeffrey (1995): 2 genres
#   Love & Human Remains (1993): 2 genres
#   Mad Love (1995): 2 genres
#   Mallrats (1995): 2 genres
#   Mighty Morphin Power Rangers: The Movie (1995): 2 genres
#   Nine Months (1995): 2 genres
#   Reckless (1995): 2 genres
#   "Scarlet Letter: 2 genres
#   Smoke (1995): 2 genres
#   Species (1995): 2 genres
#   Three Wishes (1995): 2 genres
#   Total Eclipse (1995): 2 genres
#   Unstrung Heroes (1995): 2 genres
#   "Walk in the Clouds: 2 genres
#   Before the Rain (Pred dozhdot) (1994): 2 genres
#   Before Sunrise (1995): 2 genres
#   "Babysitter: 2 genres
#   Boys on the Side (1995): 2 genres
#   Circle of Friends (1995): 2 genres
#   Disclosure (1994): 2 genres
#   Drop Zone (1994): 2 genres
#   Death and the Maiden (1994): 2 genres
#   Dolores Claiborne (1995): 2 genres
#   Dumb & Dumber (Dumb and Dumber) (1994): 2 genres
#   Ed Wood (1994): 2 genres
#   Forget Paris (1995): 2 genres
#   Far From Home: The Adventures of Yellow Dog (1995): 2 genres
#   Fluke (1995): 2 genres
#   Farinelli: il castrato (1994): 2 genres
#   Heavenly Creatures (1994): 2 genres
#   Immortal Beloved (1994): 2 genres
#   Heavyweights (Heavy Weights) (1995): 2 genres
#   I.Q. (1994): 2 genres
#   Interview with the Vampire: The Vampire Chronicles (1994): 2 genres
#   Junior (1994): 2 genres
#   Just Cause (1995): 2 genres
#   "Little Princess: 2 genres
#   Love Affair (1994): 2 genres
#   "Madness of King George: 2 genres
#   Milk Money (1994): 2 genres
#   Murder in the First (1995): 2 genres
#   New Jersey Drive (1995): 2 genres
#   New York Cop (Nyû Yôku no koppu) (1993): 2 genres
#   Beyond Bedlam (1993): 2 genres
#   Nina Takes a Lover (1994): 2 genres
#   Only You (1994): 2 genres
#   Once Were Warriors (1994): 2 genres
#   Poison Ivy II (1996): 2 genres
#   "Perez Family: 2 genres
#   "Pyromaniac's Love Story: 2 genres
#   Picture Bride (Bijo photo) (1994): 2 genres
#   "Queen Margot (Reine Margot: 2 genres
#   Roommates (1995): 2 genres
#   Three Colors: White (Trzy kolory: Bialy) (1994): 2 genres
#   Relative Fear (1994): 2 genres
#   "Swan Princess: 2 genres
#   "Shawshank Redemption: 2 genres
#   Suture (1993): 2 genres
#   Swimming with Sharks (1995): 2 genres
#   "Sum of Us: 2 genres
#   Tales from the Crypt Presents: Demon Knight (1995): 2 genres
#   Village of the Damned (1995): 2 genres
#   Underneath (1995): 2 genres
#   "Walking Dead: 2 genres
#   While You Were Sleeping (1995): 2 genres
#   "Adventures of Priscilla: 2 genres
#   Backbeat (1993): 2 genres
#   Crooklyn (1994): 2 genres
#   Four Weddings and a Funeral (1994): 2 genres
#   I Love Trouble (1994): 2 genres
#   Naked Gun 33 1/3: The Final Insult (1994): 2 genres
#   "Paper: 2 genres
#   Richie Rich (1994): 2 genres
#   "River Wild: 2 genres
#   Speechless (1994): 2 genres
#   When a Man Loves a Woman (1994): 2 genres
#   "Low Down Dirty Shame: 2 genres
#   Jason's Lyric (1994): 2 genres
#   Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994): 2 genres
#   In the Mouth of Madness (1995): 2 genres
#   Above the Rim (1994): 2 genres
#   Another Stakeout (1993): 2 genres
#   Barcelona (1994): 2 genres
#   Blown Away (1994): 2 genres
#   Blue Sky (1994): 2 genres
#   Calendar Girl (1993): 2 genres
#   Carlito's Way (1993): 2 genres
#   Coneheads (1993): 2 genres
#   Color of Night (1994): 2 genres
#   Dave (1993): 2 genres
#   Even Cowgirls Get the Blues (1993): 2 genres
#   Farewell My Concubine (Ba wang bie ji) (1993): 2 genres
#   With Honors (1994): 2 genres
#   For Love or Money (1993): 2 genres
#   "Firm: 2 genres
#   Geronimo: An American Legend (1993): 2 genres
#   Go Fish (1994): 2 genres
#   "Englishman Who Went Up a Hill But Came Down a Mountain: 2 genres
#   "House of the Spirits: 2 genres
#   I'll Do Anything (1994): 2 genres
#   In the Army Now (1994): 2 genres
#   In the Line of Fire (1993): 2 genres
#   "Inkwell: 2 genres
#   What's Love Got to Do with It? (1993): 2 genres
#   Kalifornia (1993): 2 genres
#   Lassie (1994): 2 genres
#   Lightning Jack (1994): 2 genres
#   M. Butterfly (1993): 2 genres
#   Manhattan Murder Mystery (1993): 2 genres
#   Much Ado About Nothing (1993): 2 genres
#   Mr. Wonderful (1993): 2 genres
#   Mrs. Doubtfire (1993): 2 genres
#   "Piano: 2 genres
#   "Program: 2 genres
#   "Puppet Masters: 2 genres
#   "Remains of the Day: 2 genres
#   Renaissance Man (1994): 2 genres
#   Romeo Is Bleeding (1993): 2 genres
#   Romper Stomper (1992): 2 genres
#   Schindler's List (1993): 2 genres
#   "Scout: 2 genres
#   "Secret Garden: 2 genres
#   Shadowlands (1993): 2 genres
#   Striking Distance (1993): 2 genres
#   Thirty-Two Short Films About Glenn Gould (1993): 2 genres
#   Threesome (1994): 2 genres
#   True Romance (1993): 2 genres
#   Welcome to the Dollhouse (1995): 2 genres
#   Germinal (1993): 2 genres
#   Kika (1993): 2 genres
#   Bhaji on the Beach (1993): 2 genres
#   Little Big League (1994): 2 genres
#   Spanking the Monkey (1994): 2 genres
#   "Little Rascals: 2 genres
#   "Escort: 2 genres
#   Dear Diary (Caro Diario) (1994): 2 genres
#   Home Alone (1990): 2 genres
#   Terminator 2: Judgment Day (1991): 2 genres
#   Pretty Woman (1990): 2 genres
#   "Wild Bunch: 2 genres
#   One Fine Day (1996): 2 genres
#   Candyman: Farewell to the Flesh (1995): 2 genres
#   Homeward Bound II: Lost in San Francisco (1996): 2 genres
#   Jane Eyre (1996): 2 genres
#   Bread and Chocolate (Pane e cioccolata) (1973): 2 genres
#   "Aristocats: 2 genres
#   "Flower of My Secret: 2 genres
#   Two Much (1995): 2 genres
#   "Last Supper: 2 genres
#   Land and Freedom (Tierra y libertad) (1995): 2 genres
#   "Family Thing: 2 genres
#   Girl 6 (1996): 2 genres
#   Diabolique (1996): 2 genres
#   Cold Fever (Á köldum klaka) (1995): 2 genres
#   Mystery Science Theater 3000: The Movie (1996): 2 genres
#   Some Folks Call It a Sling Blade (1993): 2 genres
#   Mrs. Winterbourne (1996): 2 genres
#   True Crime (1996): 2 genres
#   Feeling Minnesota (1996): 2 genres
#   "Quest: 2 genres
#   "Truth About Cats & Dogs: 2 genres
#   Flipper (1996): 2 genres
#   "Horseman on the Roof: 2 genres
#   Heaven's Prisoners (1996): 2 genres
#   Barb Wire (1996): 2 genres
#   Ghost in the Shell (Kôkaku kidôtai) (1995): 2 genres
#   Thinner (1996): 2 genres
#   Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964): 2 genres
#   Stalingrad (1993): 2 genres
#   "Phantom: 2 genres
#   Striptease (1996): 2 genres
#   Heavy (1995): 2 genres
#   Jack (1996): 2 genres
#   Spirits of the Dead (1968): 2 genres
#   'Til There Was You (1997): 2 genres
#   "Fan: 2 genres
#   "Cable Guy: 2 genres
#   Harriet the Spy (1996): 2 genres
#   Phenomenon (1996): 2 genres
#   She's the One (1996): 2 genres
#   "Time to Kill: 2 genres
#   American Buffalo (1996): 2 genres
#   Alaska (1996): 2 genres
#   Fled (1996): 2 genres
#   Kaspar Hauser (1993): 2 genres
#   "Adventures of Pinocchio: 2 genres
#   Ransom (1996): 2 genres
#   "Crow: City of Angels: 2 genres
#   House Arrest (1996): 2 genres
#   Tales from the Crypt Presents: Bordello of Blood (1996): 2 genres
#   "Godfather: 2 genres
#   Carpool (1996): 2 genres
#   "Relic: 2 genres
#   "Island of Dr. Moreau: 2 genres
#   First Kid (1996): 2 genres
#   "Trigger Effect: 2 genres
#   1-900 (06) (1994): 2 genres
#   Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995): 2 genres
#   "American in Paris: 2 genres
#   Funny Face (1957): 2 genres
#   Breakfast at Tiffany's (1961): 2 genres
#   Rear Window (1954): 2 genres
#   It Happened One Night (1934): 2 genres
#   Gaslight (1944): 2 genres
#   Some Like It Hot (1959): 2 genres
#   Casablanca (1942): 2 genres
#   "Maltese Falcon: 2 genres
#   Sabrina (1954): 2 genres
#   Citizen Kane (1941): 2 genres
#   "Affair to Remember: 2 genres
#   "Band Wagon: 2 genres
#   Ninotchka (1939): 2 genres
#   Love in the Afternoon (1957): 2 genres
#   My Man Godfrey (1936): 2 genres
#   "Thin Man: 2 genres
#   His Girl Friday (1940): 2 genres
#   Around the World in 80 Days (1956): 2 genres
#   Bringing Up Baby (1938): 2 genres
#   Penny Serenade (1941): 2 genres
#   Meet John Doe (1941): 2 genres
#   "Farewell to Arms: 2 genres
#   Nothing Personal (1995): 2 genres
#   "Pompatus of Love: 2 genres
#   Fly Away Home (1996): 2 genres
#   Bliss (1997): 2 genres
#   Grace of My Heart (1996): 2 genres
#   Big Night (1996): 2 genres
#   Set It Off (1996): 2 genres
#   2 Days in the Valley (1996): 2 genres
#   Extreme Measures (1996): 2 genres
#   "Glimmer Man: 2 genres
#   D3: The Mighty Ducks (1996): 2 genres
#   "Davy Crockett: 2 genres
#   "Love Bug: 2 genres
#   Old Yeller (1957): 2 genres
#   "Shaggy Dog: 2 genres
#   Swiss Family Robinson (1960): 2 genres
#   Angels in the Outfield (1994): 2 genres
#   Robin Hood: Prince of Thieves (1991): 2 genres
#   "Sound of Music: 2 genres
#   That Thing You Do! (1996): 2 genres
#   To Gillian on Her 37th Birthday (1996): 2 genres
#   Beautiful Thing (1996): 2 genres
#   "Ghost and the Darkness: 2 genres
#   Looking for Richard (1996): 2 genres
#   William Shakespeare's Romeo + Juliet (1996): 2 genres
#   Swingers (1996): 2 genres
#   Crossfire (1947): 2 genres
#   Sleeper (1973): 2 genres
#   Bananas (1971): 2 genres
#   "Fish Called Wanda: 2 genres
#   "Great Race: 2 genres
#   Bonnie and Clyde (1967): 2 genres
#   "Old Man and the Sea: 2 genres
#   Platoon (1986): 2 genres
#   Top Gun (1986): 2 genres
#   "Funeral: 2 genres
#   "People vs. Larry Flynt: 2 genres
#   "Return of the Pink Panther: 2 genres
#   Drop Dead Fred (1991): 2 genres
#   "Howling: 2 genres
#   Jean de Florette (1986): 2 genres
#   "Tin Drum: 2 genres
#   "Ruling Class: 2 genres
#   "Cook the Thief His Wife & Her Lover: 2 genres
#   Enchanted April (1992): 2 genres
#   Paths of Glory (1957): 2 genres
#   Mediterraneo (1991): 2 genres
#   Strictly Ballroom (1992): 2 genres
#   Madonna: Truth or Dare (1991): 2 genres
#   Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981): 2 genres
#   Brazil (1985): 2 genres
#   Goodfellas (1990): 2 genres
#   Alien (1979): 2 genres
#   Ran (1985): 2 genres
#   Psycho (1960): 2 genres
#   "Godfather: Part II: 2 genres
#   Full Metal Jacket (1987): 2 genres
#   "Quiet Man: 2 genres
#   Once Upon a Time in America (1984): 2 genres
#   Annie Hall (1977): 2 genres
#   "Sting: 2 genres
#   Glory (1989): 2 genres
#   Rosencrantz and Guildenstern Are Dead (1990): 2 genres
#   8 1/2 (8½) (1963): 2 genres
#   Better Off Dead... (1985): 2 genres
#   Stand by Me (1986): 2 genres
#   "Deer Hunter: 2 genres
#   Unforgiven (1992): 2 genres
#   Pump Up the Volume (1990): 2 genres
#   Patton (1970): 2 genres
#   Young Frankenstein (1974): 2 genres
#   Night on Earth (1991): 2 genres
#   High Noon (1952): 2 genres
#   Somewhere in Time (1980): 2 genres
#   Some Kind of Wonderful (1987): 2 genres
#   Indiana Jones and the Last Crusade (1989): 2 genres
#   Being There (1979): 2 genres
#   "Room with a View: 2 genres
#   Pink Floyd: The Wall (1982): 2 genres
#   "Killing Fields: 2 genres
#   My Life as a Dog (Mitt liv som hund) (1985): 2 genres
#   Forbidden Planet (1956): 2 genres
#   Father of the Bride Part II (1995): 1 genres
#   Sudden Death (1995): 1 genres
#   Nixon (1995): 1 genres
#   Four Rooms (1995): 1 genres
#   Ace Ventura: When Nature Calls (1995): 1 genres
#   Othello (1995): 1 genres
#   Dangerous Minds (1995): 1 genres
#   "Cry: 1 genres
#   Restoration (1995): 1 genres
#   Georgia (1995): 1 genres
#   Home for the Holidays (1995): 1 genres
#   Mr. Holland's Opus (1995): 1 genres
#   Bio-Dome (1996): 1 genres
#   Friday (1995): 1 genres
#   Fair Game (1995): 1 genres
#   Nico Icon (1995): 1 genres
#   Black Sheep (1996): 1 genres
#   Heidi Fleiss: Hollywood Madam (1995): 1 genres
#   Mr. Wrong (1996): 1 genres
#   Happy Gilmore (1996): 1 genres
#   Catwalk (1996): 1 genres
#   Anne Frank Remembered (1995): 1 genres
#   "Steal Big: 1 genres
#   "Boys of St. Vincent: 1 genres
#   Flirting With Disaster (1996): 1 genres
#   Jupiter's Wife (1994): 1 genres
#   Jade (1995): 1 genres
#   Down Periscope (1996): 1 genres
#   Man of the Year (1995): 1 genres
#   "Birdcage: 1 genres
#   "Brothers McMullen: 1 genres
#   "Basketball Diaries: 1 genres
#   "Awfully Big Adventure: 1 genres
#   Beauty of the Day (Belle de jour) (1967): 1 genres
#   Crumb (1994): 1 genres
#   Jury Duty (1995): 1 genres
#   Kids (1995): 1 genres
#   Living in Oblivion (1995): 1 genres
#   Lord of Illusions (1995): 1 genres
#   Nadja (1994): 1 genres
#   Party Girl (1995): 1 genres
#   Safe (1995): 1 genres
#   Showgirls (1995): 1 genres
#   "To Wong Foo: 1 genres
#   Under Siege 2: Dark Territory (1995): 1 genres
#   Unzipped (1995): 1 genres
#   White Man's Burden (1995): 1 genres
#   Wild Bill (1995): 1 genres
#   "Browning Version: 1 genres
#   Burnt by the Sun (Utomlyonnye solntsem) (1994): 1 genres
#   Billy Madison (1995): 1 genres
#   "Cure: 1 genres
#   Castle Freak (1995): 1 genres
#   Clerks (1994): 1 genres
#   Destiny Turns on the Radio (1995): 1 genres
#   Exotica (1994): 1 genres
#   Exit to Eden (1994): 1 genres
#   Hideaway (1995): 1 genres
#   Hoop Dreams (1994): 1 genres
#   Houseguest (1994): 1 genres
#   "Hunted: 1 genres
#   Jefferson in Paris (1995): 1 genres
#   "Jerky Boys: 1 genres
#   Little Women (1994): 1 genres
#   Ladybird Ladybird (1994): 1 genres
#   Major Payne (1995): 1 genres
#   My Crazy Life (Mi vida loca) (1993): 1 genres
#   Losing Isaiah (1995): 1 genres
#   Man of the House (1995): 1 genres
#   Mixed Nuts (1994): 1 genres
#   Miracle on 34th Street (1994): 1 genres
#   Miami Rhapsody (1995): 1 genres
#   My Family (1995): 1 genres
#   Nell (1994): 1 genres
#   Pushing Hands (Tui shou) (1992): 1 genres
#   Priest (1994): 1 genres
#   Quiz Show (1994): 1 genres
#   Ready to Wear (Pret-A-Porter) (1994): 1 genres
#   Three Colors: Red (Trois couleurs: Rouge) (1994): 1 genres
#   Three Colors: Blue (Trois couleurs: Bleu) (1993): 1 genres
#   Rent-a-Kid (1995): 1 genres
#   Stuart Saves His Family (1995): 1 genres
#   Strawberry and Chocolate (Fresa y chocolate) (1993): 1 genres
#   National Lampoon's Senior Trip (1995): 1 genres
#   To Live (Huozhe) (1994): 1 genres
#   Tom & Viv (1994): 1 genres
#   Tommy Boy (1995): 1 genres
#   Vanya on 42nd Street (1994): 1 genres
#   What's Eating Gilbert Grape (1993): 1 genres
#   Double Happiness (1994): 1 genres
#   Muriel's Wedding (1994): 1 genres
#   "Baby-Sitters Club: 1 genres
#   Ace Ventura: Pet Detective (1994): 1 genres
#   Bullets Over Broadway (1994): 1 genres
#   Cobb (1994): 1 genres
#   Higher Learning (1995): 1 genres
#   "Wonderful: 1 genres
#   Little Buddha (1993): 1 genres
#   Mrs. Parker and the Vicious Circle (1994): 1 genres
#   Red Rock West (1992): 1 genres
#   Wyatt Earp (1994): 1 genres
#   "Man of No Importance: 1 genres
#   S.F.W. (1994): 1 genres
#   Boys Life (1995): 1 genres
#   Federal Hill (1994): 1 genres
#   8 Seconds (1994): 1 genres
#   "Age of Innocence: 1 genres
#   Airheads (1994): 1 genres
#   "Air Up There: 1 genres
#   Bad Girls (1994): 1 genres
#   Being Human (1993): 1 genres
#   "Beverly Hillbillies: 1 genres
#   Blink (1994): 1 genres
#   Blue Chips (1994): 1 genres
#   "Bronx Tale: 1 genres
#   Cabin Boy (1994): 1 genres
#   Clean Slate (1994): 1 genres
#   Cops and Robbersons (1994): 1 genres
#   Dazed and Confused (1993): 1 genres
#   Fatal Instinct (1993): 1 genres
#   Fearless (1993): 1 genres
#   Fear of a Black Hat (1994): 1 genres
#   Widows' Peak (1994): 1 genres
#   "Fugitive: 1 genres
#   Getting Even with Dad (1994): 1 genres
#   Live Nude Girls (1995): 1 genres
#   House Party 3 (1994): 1 genres
#   "Hudsucker Proxy: 1 genres
#   In the Name of the Father (1993): 1 genres
#   Life with Mikey (1993): 1 genres
#   Made in America (1993): 1 genres
#   Malice (1993): 1 genres
#   "Man Without a Face: 1 genres
#   In the Realm of the Senses (Ai no corrida) (1976): 1 genres
#   Naked (1993): 1 genres
#   North (1994): 1 genres
#   Philadelphia (1993): 1 genres
#   Poetic Justice (1993): 1 genres
#   "Ref: 1 genres
#   "Road to Wellville: 1 genres
#   Robin Hood: Men in Tights (1993): 1 genres
#   Ruby in Paradise (1993): 1 genres
#   Rudy (1993): 1 genres
#   "Savage Nights (Nuits fauves: 1 genres
#   Searching for Bobby Fischer (1993): 1 genres
#   Short Cuts (1993): 1 genres
#   "Simple Twist of Fate: 1 genres
#   Sirens (1994): 1 genres
#   Six Degrees of Separation (1993): 1 genres
#   Sliver (1993): 1 genres
#   "War Room: 1 genres
#   Chasers (1994): 1 genres
#   "Ciao: 1 genres
#   Princess Caraboo (1994): 1 genres
#   "Celluloid Closet: 1 genres
#   "Brady Bunch Movie: 1 genres
#   "Great Day in Harlem: 1 genres
#   "Pallbearer: 1 genres
#   Ed (1996): 1 genres
#   "Thin Line Between Love and Hate: 1 genres
#   Denise Calls Up (1995): 1 genres
#   Theodore Rex (1995): 1 genres
#   Frisk (1995): 1 genres
#   Sgt. Bilko (1996): 1 genres
#   Jack and Sarah (1995): 1 genres
#   Nelly & Monsieur Arnaud (1995): 1 genres
#   Moll Flanders (1996): 1 genres
#   Eddie (1996): 1 genres
#   Fear (1996): 1 genres
#   Kids in the Hall: Brain Candy (1996): 1 genres
#   Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996): 1 genres
#   Song of the Little Road (Pather Panchali) (1955): 1 genres
#   "World of Apu: 1 genres
#   "Run of the Country: 1 genres
#   It's My Party (1996): 1 genres
#   Delta of Venus (1995): 1 genres
#   Angus (1995): 1 genres
#   Boys (1996): 1 genres
#   Sunset Park (1996): 1 genres
#   Celtic Pride (1996): 1 genres
#   Multiplicity (1996): 1 genres
#   "Haunted World of Edward D. Wood Jr.: 1 genres
#   "Great White Hype: 1 genres
#   Last Dance (1996): 1 genres
#   Cold Comfort Farm (1995): 1 genres
#   Cemetery Man (Dellamorte Dellamore) (1994): 1 genres
#   Spy Hard (1996): 1 genres
#   "Stupids: 1 genres
#   Ashes of Time (Dung che sai duk) (1994): 1 genres
#   Maya Lin: A Strong Clear Vision (1994): 1 genres
#   I Shot Andy Warhol (1996): 1 genres
#   Touki Bouki (1973): 1 genres
#   Stealing Beauty (1996): 1 genres
#   Kingpin (1996): 1 genres
#   "Unforgettable Summer: 1 genres
#   "Last Klezmer: Leopold Kozlowski: 1 genres
#   Somebody to Love (1994): 1 genres
#   Larger Than Life (1996): 1 genres
#   "Very Brady Sequel: 1 genres
#   "Collector: 1 genres
#   "First Wives Club: 1 genres
#   High School High (1996): 1 genres
#   Foxfire (1996): 1 genres
#   "Eyes Without a Face (Yeux sans visage: 1 genres
#   "Spitfire Grill: 1 genres
#   Basquiat (1996): 1 genres
#   Gone Fishin' (1997): 1 genres
#   Mother Night (1996): 1 genres
#   Wild Reeds (Les roseaux sauvages) (1994): 1 genres
#   Meet Me in St. Louis (1944): 1 genres
#   My Favorite Year (1982): 1 genres
#   All About Eve (1950): 1 genres
#   "Women: 1 genres
#   Father of the Bride (1950): 1 genres
#   Gigi (1958): 1 genres
#   "Mark of Zorro: 1 genres
#   Lost Horizon (1937): 1 genres
#   East of Eden (1955): 1 genres
#   Mr. Smith Goes to Washington (1939): 1 genres
#   Of Human Bondage (1934): 1 genres
#   Little Lord Fauntleroy (1936): 1 genres
#   "Inspector General: 1 genres
#   Cat on a Hot Tin Roof (1958): 1 genres
#   Dangerous Ground (1997): 1 genres
#   Picnic (1955): 1 genres
#   Michael Collins (1996): 1 genres
#   Infinity (1996): 1 genres
#   "Chamber: 1 genres
#   Cool Runnings (1993): 1 genres
#   "Secret Agent: 1 genres
#   Secrets & Lies (1996): 1 genres
#   Trees Lounge (1996): 1 genres
#   Get on the Bus (1996): 1 genres
#   Shadow Conspiracy (1997): 1 genres
#   Jude (1996): 1 genres
#   Sleepers (1996): 1 genres
#   Monty Python's Life of Brian (1979): 1 genres
#   "Candidate: 1 genres
#   Weekend at Bernie's (1989): 1 genres
#   "Doors: 1 genres
#   Glengarry Glen Ross (1992): 1 genres
#   Sophie's Choice (1982): 1 genres
#   Rebel Without a Cause (1955): 1 genres
#   "Streetcar Named Desire: 1 genres
#   Children of the Corn IV: The Gathering (1996): 1 genres
#   Loser (1991): 1 genres
#   Microcosmos (Microcosmos: Le peuple de l'herbe) (1996): 1 genres
#   "Single Girl: 1 genres
#   "Eighth Day: 1 genres
#   Drunks (1995): 1 genres
#   Glory Daze (1995): 1 genres
#   "Perfect Candidate: 1 genres
#   On Golden Pond (1981): 1 genres
#   "Fog: 1 genres
#   Manon of the Spring (Manon des sources) (1986): 1 genres
#   Private Benjamin (1980): 1 genres
#   Hustler White (1996): 1 genres
#   Entertaining Angels: The Dorothy Day Story (1996): 1 genres
#   "Line King: The Al Hirschfeld Story: 1 genres
#   When We Were Kings (1996): 1 genres
#   "Return of Martin Guerre: 1 genres
#   "Children Are Watching Us: 1 genres
#   Mina Tannenbaum (1994): 1 genres
#   Dear God (1996): 1 genres
#   Best of the Best 3: No Turning Back (1995): 1 genres
#   Bob Roberts (1992): 1 genres
#   Cinema Paradiso (Nuovo cinema Paradiso) (1989): 1 genres
#   Hear My Song (1991): 1 genres
#   My Left Foot (1989): 1 genres
#   "Sex: 1 genres
#   Passion Fish (1992): 1 genres
#   "Thin Blue Line: 1 genres
#   Paris Is Burning (1990): 1 genres
#   One Flew Over the Cuckoo's Nest (1975): 1 genres
#   Cheech and Chong's Up in Smoke (1978): 1 genres
#   Withnail & I (1987): 1 genres
#   12 Angry Men (1957): 1 genres
#   To Kill a Mockingbird (1962): 1 genres
#   Amadeus (1984): 1 genres
#   Raging Bull (1980): 1 genres
#   "Right Stuff: 1 genres
#   "Seventh Seal: 1 genres
#   Local Hero (1983): 1 genres
#   Dead Poets Society (1989): 1 genres
#   "Shining: 1 genres
#   Cool Hand Luke (1967): 1 genres
#   Raise the Red Lantern (Da hong deng long gao gao gua) (1991): 1 genres
#   Heathers (1989): 1 genres
#   This Is Spinal Tap (1984): 1 genres
#   Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983): 1 genres
#   Gandhi (1982): 1 genres
#   "Unbearable Lightness of Being: 1 genres
#   Real Genius (1985): 1 genres

# %% [markdown]
# And examining the final class - Tags

# %%
tags = Tags('data/ml-latest-small/tags.csv')

# %%
print('Top-5 tags with most words')
# %timeit tags.most_words(5)
most_wordy = tags.most_words(5)
print('Examining tags with most words helps understand how detailed user descriptions are.')
for tag, count in most_wordy.items():
    print(f"'{tag}' - {count} words")
# Out:
# Top-5 tags with most words
# 831 μs ± 41.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Examining tags with most words helps understand how detailed user descriptions are.
# 'Something for everyone in this one... saw it without and plan on seeing it with kids!' - 16 words
# 'the catholic church is the most corrupt organization in history' - 10 words
# 'Oscar (Best Music - Original Score)' - 6 words
# 'Everything you want is here' - 5 words
# 'based on a true story' - 5 words

# %%
print('Top-5 longest tags')
# %timeit tags.longest(5)
longest_tags = tags.longest(5)
print('Analyzing longest tags by character count shows user description detail level.')
for tag in longest_tags:
    print(f"'{tag}'")
# Out:
# Top-5 longest tags
# 651 μs ± 33.8 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Analyzing longest tags by character count shows user description detail level.
# 'Something for everyone in this one... saw it without and plan on seeing it with kids!'
# 'the catholic church is the most corrupt organization in history'
# 'audience intelligence underestimated'
# 'Oscar (Best Music - Original Score)'
# 'assassin-in-training (scene)'

# %%
print('Intersection of most word-rich and longest tags (top-5)')
# %timeit tags.most_words_and_longest(5)
intersection = tags.most_words_and_longest(5)
print('Finding tags that are both word-rich and long may indicate especially detailed descriptions.')
for tag in intersection:
    print(f"'{tag}'")
# Out:
# Intersection of most word-rich and longest tags (top-5)
# 1.44 ms ± 22.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Finding tags that are both word-rich and long may indicate especially detailed descriptions.
# 'Oscar (Best Music - Original Score)'
# 'Something for everyone in this one... saw it without and plan on seeing it with kids!'
# 'the catholic church is the most corrupt organization in history'

# %%
print('Top-5 most popular tags')
# %timeit tags.most_popular(5)
popular = tags.most_popular(5)
print('Examining most frequently used tags helps understand popular movie aspects.')
for tag, count in popular.items():
    print(f"'{tag}' - {count} times")
# Out:
# Top-5 most popular tags
# 637 μs ± 14.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Examining most frequently used tags helps understand popular movie aspects.
# 'funny' - 15 times
# 'sci-fi' - 14 times
# 'dark comedy' - 12 times
# 'twist ending' - 12 times
# 'action' - 10 times

# %%
print('All tags containing word "sci"')
# %timeit tags.tags_with('sci')
sci_tags = tags.tags_with('sci')
print('Finding all tags containing "sci" to understand how users describe science fiction.')
for tag in sci_tags:
    print(f"'{tag}'")
# Out:
# All tags containing word "sci"
# 191 μs ± 5.4 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# Finding all tags containing "sci" to understand how users describe science fiction.
# 'Sci-Fi'
# 'classic sci-fi'
# 'mad scientist'
# 'sci-fi'
# 'science fiction'
# 'scifi'
# 'scifi cult'
# 'sexy female scientist'

# %%
print('Top-3 tags for movie ID 60756')
# %timeit tags.most_popular_by_movie(60756, 3)
popular_for_movie = tags.most_popular_by_movie(60756, 3)
print('Analyzing tags for specific movies gives insight into user perception.')
for tag, count in popular_for_movie.items():
    print(f"'{tag}' - {count} times")
# Out:
# Top-3 tags for movie ID 60756
# 196 μs ± 10 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# Analyzing tags for specific movies gives insight into user perception.
# 'funny' - 3 times
# 'will ferrell' - 3 times
# 'Highly quotable' - 1 times

# %%
print('Average tag length')
# %timeit tags.average_tag_length()
avg_len = tags.average_tag_length()
print('Average tag length shows overall user description detail level.')
print(f'{avg_len:.2f} characters')
# Out:
# Average tag length
# 98.7 μs ± 4.36 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# Average tag length shows overall user description detail level.
# 10.71 characters

# %%
print('Total unique tags count')
print('Shows diversity of tags used by users.')
# %timeit tags.get_unique_tags_count()
unique_count = tags.get_unique_tags_count()
print(f'{unique_count} tags')
# Out:
# Total unique tags count
# Shows diversity of tags used by users.
# 127 μs ± 3.99 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 602 tags

# %% [markdown]
# Finish!
